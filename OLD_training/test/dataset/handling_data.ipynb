# %%
import pandas as pd
df = pd.read_csv('TEST_CLEAN_NO_DUPLICATES.csv')
df.columns
# Out:
# Index(['title', 'text', 'label', 'title_clean', 'text_clean'], dtype='str')

# %%
df_2=pd.read_csv('TEST_CLEAN_NO_DUPLICATES_WITH_MATCHES.csv')
df_2.columns
# Out:
# Index(['title', 'text', 'label', 'empresa(s)', 'fraude', 'title_clean',
#        'text_clean'],
#       dtype='str')

# %%
df_3 = pd.read_csv('TEST_PREPROCESSED.csv')
df_3.columns
# Out:
# Index(['title', 'text', 'label', 'title_clean', 'text_clean'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['title', 'text', 'label'], dtype='str')

# %%
print(df_2.columns)
# Out:
# Index(['title', 'text', 'label', 'empresa(s)', 'fraude', 'title_clean',
#        'text_clean'],
#       dtype='str')

# %%
df_2['label'].value_counts()
# Out:
# label
# 1    175
# Name: count, dtype: int64

# %%
df_2.head()
