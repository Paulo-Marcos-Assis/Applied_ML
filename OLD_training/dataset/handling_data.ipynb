# %%
import pandas as pd
df = pd.read_csv('DF_COMPANIES_CLEAN.csv')
df.head(15)
# Out:
#     Unnamed: 0                                                url  Unnamed: 2  \
# 0          NaN  https://www.mpsc.mp.br/noticias/em-irani-dois-...         NaN
# 1          NaN  https://www.mpsc.mp.br/noticias/ex-prefeito-de...         NaN
# 2          NaN  https://omunicipio.com.br/ex-prefeito-de-botuv...         NaN
# 3          NaN                      https://pc.sc.gov.br/?p=18630         NaN
# 4          NaN                       https://pc.sc.gov.br/?p=5310         NaN
# 5          NaN  https://g1.globo.com/sc/santa-catarina/noticia...         NaN
# 6          NaN  https://g1.globo.com/sc/santa-catarina/noticia...         NaN
# 7          NaN  https://www.cnnbrasil.com.br/nacional/operacao...         NaN
# 8          NaN  https://intranet.mpsc.mp.br/noticias/gaeco-e-g...         NaN
# 9          NaN  https://www.mpsc.mp.br/noticias/gaeco-deflagra...         NaN
# 10         NaN  https://portal.mpsc.mp.br/noticias/ex-secretar...         NaN
# ...

# %%
print(df.loc[8])
# Out:
# Unnamed: 0                                                        NaN
# url                 https://intranet.mpsc.mp.br/noticias/gaeco-e-g...
# Unnamed: 2                                                        NaN
# title               gaeco e geac deflagram segunda fase da operaçã...
# Unnamed: 4                                                        NaN
# text                gaeco e geac deflagram segunda fase da operaçã...
# Unnamed: 6                                                        NaN
# empresa(s)                                     Dygi Comunicação Ltda.
# Unnamed: 8                                                        NaN
# pessoa(s)            Luísa Niencheski Calviera (promotora de justiça)
# Unnamed: 10                                                       NaN
# fraude              fraude em licitações, desvio de recursos públicos
# Unnamed: 12                                                       NaN
# ...

# %%
df=df.drop(index=8)
df=df.reset_index(drop=True)
df.head(15)
# Out:
#     Unnamed: 0                                                url  Unnamed: 2  \
# 0          NaN  https://www.mpsc.mp.br/noticias/em-irani-dois-...         NaN
# 1          NaN  https://www.mpsc.mp.br/noticias/ex-prefeito-de...         NaN
# 2          NaN  https://omunicipio.com.br/ex-prefeito-de-botuv...         NaN
# 3          NaN                      https://pc.sc.gov.br/?p=18630         NaN
# 4          NaN                       https://pc.sc.gov.br/?p=5310         NaN
# 5          NaN  https://g1.globo.com/sc/santa-catarina/noticia...         NaN
# 6          NaN  https://g1.globo.com/sc/santa-catarina/noticia...         NaN
# 7          NaN  https://www.cnnbrasil.com.br/nacional/operacao...         NaN
# 8          NaN  https://intranet.mpsc.mp.br/noticias/gaeco-e-g...         NaN
# 9          NaN  https://www.mpsc.mp.br/noticias/gaeco-deflagra...         NaN
# 10         NaN  https://portal.mpsc.mp.br/noticias/ex-secretar...         NaN
# ...

# %%
print(df.shape)
# Out:
# (1050, 14)

# %%
df.columns
# Out:
# Index(['url', 'title', 'text', 'empresa(s)', 'pessoa(s)', 'fraude',
#        'date_publication'],
#       dtype='str')

# %%
df=df.drop(columns=['Unnamed: 0', 'Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8', 'Unnamed: 10', 'Unnamed: 12'])

# %%
df.head(15)
# Out:
#                                                   url  \
# 0   https://www.mpsc.mp.br/noticias/em-irani-dois-...
# 1   https://www.mpsc.mp.br/noticias/ex-prefeito-de...
# 2   https://omunicipio.com.br/ex-prefeito-de-botuv...
# 3                       https://pc.sc.gov.br/?p=18630
# 4                        https://pc.sc.gov.br/?p=5310
# 5   https://g1.globo.com/sc/santa-catarina/noticia...
# 6   https://g1.globo.com/sc/santa-catarina/noticia...
# 7   https://www.cnnbrasil.com.br/nacional/operacao...
# 8   https://intranet.mpsc.mp.br/noticias/gaeco-e-g...
# 9   https://www.mpsc.mp.br/noticias/gaeco-deflagra...
# 10  https://portal.mpsc.mp.br/noticias/ex-secretar...
# 11  https://www.nsctotal.com.br/noticias/fraude-em...
# 12  https://www.tcesc.tc.br/informacoes-do-tcesc-e...
# 13  https://lerunica.com.br/amurel/empresarios-e-f...
# 14  https://www.mpsc.mp.br/noticias/recebida-denun...
#
#                                                 title  \
# ...
