# %%
import pandas as pd    
dff=pd.read_csv('DF_COMPANIES_REDUZIDO.csv')
print(len(dff))
# Out:
# 882

# %%
dff.columns
# Out:
# Index(['Unnamed: 0', 'url', 'Unnamed: 2', 'title', 'Unnamed: 4', 'text',
#        'Unnamed: 6', 'empresa(s)', 'Unnamed: 8', 'pessoa(s)', 'Unnamed: 10',
#        'fraude', 'Unnamed: 12', 'date_publication', 'empresas', 'pessoas'],
#       dtype='str')

# %%
a= dff.loc[dff['title'].str.contains('Clima tenso: Ricardo Salles dispara contra Eduardo Bolsonaro e Valdemar da Costa Neto')]
dff=dff.drop(a.index) 
dff=dff.reset_index(drop=True)
print(len(dff))
# Out:
# 881

# %%
dff.to_csv('DF_COMPANIES_REDUZIDO.csv', index=False)

# %%
import pandas as pd
df=pd.read_csv('NEGATIVE_DATASET_STRATIFIED.csv')
print(len(df))
print(df.columns)
print(df.head())
# Out:
# 882
# Index(['url', 'title', 'text', 'empresas', 'pessoas', 'fraude',
#        'date_publication', 'source_file', 'category', 'portal', 'word_count',
#        'label'],
#       dtype='str')
#                                                  url  \
# 0  https://jornalconexao.com.br/noticia/12489/mar...
# 1  https://jornalconexao.com.br/noticia/12460/rec...
# 2  https://jornalconexao.com.br/noticia/12477/tra...
# 3  https://jornalconexao.com.br/noticia/12475/gua...
# 4  https://jornalconexao.com.br/noticia/12485/mot...
#
#                                                title  \
# 0  Mar revolto invade faixa de areia e assusta mo...
# 1  Reconexão emocional ganha espaço em vivência e...
# 2  Tragédia em escola no Acre: adolescente armado...
# 3  Guarda municipal de Florianópolis terá nova ca...
# 4  Motorista perde controle, cai com carro em rio...
#
#                                                 text  empresas  pessoas  \
# ...

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://jornalconexao.com.br/noticia/12489/mar...
# 1  https://jornalconexao.com.br/noticia/12460/rec...
# 2  https://jornalconexao.com.br/noticia/12477/tra...
# 3  https://jornalconexao.com.br/noticia/12475/gua...
# 4  https://jornalconexao.com.br/noticia/12485/mot...
#
#                                                title  \
# 0  Mar revolto invade faixa de areia e assusta mo...
# 1  Reconexão emocional ganha espaço em vivência e...
# 2  Tragédia em escola no Acre: adolescente armado...
# 3  Guarda municipal de Florianópolis terá nova ca...
# 4  Motorista perde controle, cai com carro em rio...
#
#                                                 text  empresas  pessoas  \
# 0  A forteressacaregistrada no litoral catarinens...       NaN      NaN
# 1  Um convite ao reencontro interior marca a real...       NaN      NaN
# 2  Umadolescente de 13 anosprotagonizou um episód...       NaN      NaN
# ...

# %%
import pandas as pd
df=pd.read_csv('DF_COMPANIES_REDUZIDO.csv')
df.tail()
# Out:
#      Unnamed: 0                                                url  \
# 876         NaN  https://iclnoticias.com.br/deputado-alvo-busca...
# 877         NaN  https://www.bbc.com/portuguese/articles/c5y200...
# 878         NaN  https://www.bbc.com/portuguese/articles/c20vq0...
# 879         NaN  https://www.cartacapital.com.br/politica/tre-d...
# 880         NaN  https://www.bbc.com/portuguese/articles/c4g98g...
#
#      Unnamed: 2                                              title  \
# 876         NaN  Deputado estadual é alvo de buscas na Bahia po...
# 877         NaN  Câmara rejeita cassação de Carla Zambelli apes...
# 878         NaN  Como se saber se bebida está adulterada  — e o...
# 879         NaN  TRE de São Paulo cassa prefeito por abuso de p...
# 880         NaN  'Nº 2 da Previdência' é preso: o que se sabe s...
#
#      Unnamed: 4                                               text  \
# 876         NaN  Por João Pedro Pitombo (Folhapress) – O deputa...
# ...

# %%
df2=pd.read_csv("/home/paulo/CascadeProjects/Applied_ML/dataset/DF_COMPANIES_ORIGINAL.csv")
df2.tail()
# Out:
#       Unnamed: 0                                                url  \
# 1045         NaN  https://www.nsctotal.com.br/noticias/toffoli-s...
# 1046         NaN  https://www.nsctotal.com.br/noticias/trump-pub...
# 1047         NaN  https://www.nsctotal.com.br/colunistas/estela-...
# 1048         NaN  https://www.nsctotal.com.br/colunistas/estela-...
# 1049         NaN  https://www.nsctotal.com.br/noticias/veja-a-ma...
#
#       Unnamed: 2                                              title  \
# 1045         NaN  Toffoli se afasta da relatoria do caso Master ...
# 1046         NaN  Trump publica vídeo que mostra Michelle e Bara...
# 1047         NaN  Uso de antigas ações do Besc nas fraudes do Ma...
# 1048         NaN  Uso de antigas ações do Besc para fraude pelo ...
# 1049         NaN  Veja a mansão de R$ 450 milhões em Miami ligad...
#
#       Unnamed: 4                                               text  \
# 1045         NaN  Usuário\nMinha Conta\nSair\nRádios\nHome>DC>Po...
# ...
